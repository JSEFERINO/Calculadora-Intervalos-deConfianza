# %% [markdown]
# <a href="https://colab.research.google.com/github/JSEFERINO/Calculadora-Intervalos-deConfianza/blob/main/Intervalos_de_Confianza.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# ============================================================
# SUBIR A GITHUB DESDE COLAB
# ============================================================

# 1. Instalar git
# !apt-get install git -q

# 2. Configurar git (reemplaza con tus datos)
# !git config --global user.email "juliohur@gmail.com.com"
# !git config --global user.name "Maestro Seferino"

# 3. Clonar tu repositorio (reemplaza con tu URL)
# !git clone https://github.com/JSEFERINO/Calculadora-Intervalos-deConfianza.git
# %cd Calculadora-Intervalos-deConfianza

# 4. Copiar archivos
# !cp ../app.py .
# !cp ../requirements.txt .

# 5. Subir a GitHub
# !git add .
# !git commit -m "Añadiendo calculadora de Calculadora Intervalos de Confianza"
# !git push origin main

print("✅ Archivos subidos a GitHub")
# Out:
# Reading package lists...
# Building dependency tree...
# Reading state information...
# git is already the newest version (1:2.34.1-1ubuntu1.17).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
# fatal: destination path 'Calculadora-Intervalos-deConfianza' already exists and is not an empty directory.
# /content/Calculadora-Intervalos-deConfianza
# cp: cannot stat '../app.py': No such file or directory
# cp: cannot stat '../requirements.txt': No such file or directory
# On branch main
# Your branch is up to date with 'origin/main'.
#
# nothing to commit, working tree clean
# fatal: could not read Username for 'https://github.com': No such device or address
# ✅ Archivos subidos a GitHub
